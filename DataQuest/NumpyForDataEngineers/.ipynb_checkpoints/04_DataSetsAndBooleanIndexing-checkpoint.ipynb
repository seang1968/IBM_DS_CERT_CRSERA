# %% [markdown]
# ![image.png](attachment:da4d7e18-61d1-4865-b0ee-4f2a7062a6e5.png)

# %%
import numpy as np
print('x ->\n', x := np.array([
    [44, 70, 49,  2, 19],
    [62, 68, 64, 18, 12],
    [91, 90, 63, 98, 69],
    [22,  9, 98, 16, 58],
    [47, 92, 39,  8, 19],
    [ 1, 41,  3, 15, 71],
    [92, 18, 37, 42,  5]
])
     )
print('first_four -> \n' , first_four:=x[0:4,:])
print('last_column -> \n' , last_column:=x[:,-1])
# Out:
# x ->
#  [[44 70 49  2 19]
#  [62 68 64 18 12]
#  [91 90 63 98 69]
#  [22  9 98 16 58]
#  [47 92 39  8 19]
#  [ 1 41  3 15 71]
#  [92 18 37 42  5]]
# first_four ->
#  [[44 70 49  2 19]
#  [62 68 64 18 12]
#  [91 90 63 98 69]
#  [22  9 98 16 58]]
# last_column ->
#  [19 12 69 58 19 71  5]

# %% [markdown]
# ![image.png](attachment:cd5c49e2-42ba-459e-ba2d-1d98e69d0b59.png)

# %%
import numpy as np
print ('reading sars from file sars-> \n' ,sars := np.genfromtxt('sars.csv', delimiter=',')
      )
print('first_five -> \n', first_five:=sars[0:5,:])
# Out:
# reading sars from file sars->
#  [[      nan       nan       nan       nan       nan       nan]
#  [      nan 4.000e+00 2.000e+00 6.000e+00 0.000e+00 0.000e+00]
#  [      nan 1.510e+02 1.000e+02 2.510e+02 4.300e+01 1.700e+01]
#  [      nan 2.674e+03 2.607e+03 5.327e+03 3.490e+02 7.000e+00]
#  [      nan 9.770e+02 7.780e+02 1.755e+03 2.990e+02 1.700e+01]
#  [      nan 0.000e+00 1.000e+00 1.000e+00 0.000e+00 0.000e+00]
#  [      nan 2.180e+02 1.280e+02 3.460e+02 3.700e+01 1.100e+01]
#  [      nan 1.000e+00 6.000e+00 7.000e+00 1.000e+00 1.400e+01]
#  [      nan 4.000e+00 5.000e+00 9.000e+00 0.000e+00 0.000e+00]
#  [      nan 0.000e+00 3.000e+00 3.000e+00 0.000e+00 0.000e+00]
#  [      nan 0.000e+00 2.000e+00 2.000e+00 0.000e+00 0.000e+00]
#  [      nan 1.000e+00 3.000e+00 4.000e+00 0.000e+00 0.000e+00]
#  [      nan 1.000e+00 0.000e+00 1.000e+00 0.000e+00 0.000e+00]
#  [      nan 1.000e+00 4.000e+00 5.000e+00 2.000e+00 4.000e+01]
# ...

# %% [markdown]
# ![image.png](attachment:ea7f3fae-f2b7-48a9-ac1e-6b708a5056e6.png)

# %%
np.set_printoptions(suppress=True)
print('removing first row from sars ->\n', sars:=sars[1:,:])
print('removing first column from sars ->\n', sars:=sars[:,1:])
# Out:
# removing first row from sars ->
#  [[  nan    4.    2.    6.    0.    0.]
#  [  nan  151.  100.  251.   43.   17.]
#  [  nan 2674. 2607. 5327.  349.    7.]
#  [  nan  977.  778. 1755.  299.   17.]
#  [  nan    0.    1.    1.    0.    0.]
#  [  nan  218.  128.  346.   37.   11.]
#  [  nan    1.    6.    7.    1.   14.]
#  [  nan    4.    5.    9.    0.    0.]
#  [  nan    0.    3.    3.    0.    0.]
#  [  nan    0.    2.    2.    0.    0.]
#  [  nan    1.    3.    4.    0.    0.]
#  [  nan    1.    0.    1.    0.    0.]
#  [  nan    1.    4.    5.    2.   40.]
#  [  nan    8.    1.    9.    0.    0.]
#  [  nan    1.    0.    1.    0.    0.]
#  [  nan    8.    6.   14.    2.   14.]
#  [  nan    0.    1.    1.    0.    0.]
#  [  nan    0.    3.    3.    0.    0.]
#  [  nan    0.    1.    1.    0.    0.]
#  [  nan    0.    1.    1.    0.    0.]
#  [  nan  161.   77.  238.   33.   14.]
#  [  nan    0.    1.    1.    1.  100.]
#  [  nan    0.    1.    1.    0.    0.]
# ...

# %% [markdown]
# ![image.png](attachment:3f82ea05-6c78-4f0a-ad7b-ef8ae746a8be.png)

# %%
print('Using slicing, assign the Total column (index 2) to a 1-dimensional ndarray named total -> \n', total:=sars[:,2])
print('Using the ndarray.max() method, calculate the maximum of total and assign the result to variable max_cases -> \n ', max_cases:=total.max())
# Out:
# Using slicing, assign the Total column (index 2) to a 1-dimensional ndarray named total ->
#  [   6.  251. 5327. 1755.    1.  346.    7.    9.    3.    2.    4.    1.
#     5.    9.    1.   14.    1.    3.    1.    1.  238.    1.    1.    5.
#     1.    9.    4.   27.   63.]
# Using the ndarray.max() method, calculate the maximum of total and assign the result to variable max_cases ->
#   5327.0

# %% [markdown]
# https://app.dataquest.io/c/91/m/509/datasets-and-boolean-indexing/5/comparing-column-values

# %%
C:\pyproj\IBM_DS_CERT_CRSERA>
