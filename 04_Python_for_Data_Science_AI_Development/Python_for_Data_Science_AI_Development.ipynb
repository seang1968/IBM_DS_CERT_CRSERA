# %% [markdown]
# <html>
# <head>
# <meta content="text/html; charset=ISO-8859-1"
# http-equiv="content-type">
# <title></title>
# </head>
# <body>
# <div class="_pu0m129" id="main"
# style="position: relative; min-height: 1px; width: 576px; padding-left: 12px; padding-right: 12px;">
# <div
# class="_1bjlpa11 BannerTitle text-xs-left banner-title-container--without-subtitle"
# data-test="banner-title-container"
# style="text-align: left ! important;">
# <h1 class="banner-title banner-title-without--subtitle m-b-0"
# data-e2e="xdp-banner-title"
# style="padding: 0px; margin-top: 0px; margin-right: 0px; margin-bottom: 0px ! important; margin-left: 0px; font-size: 34px; max-width: 100%; font-family: OpenSans-Bold,Arial,sans-serif; line-height: 46px; font-weight: 700; color: inherit;">Python
# for Data Science, AI &amp; Development</h1>
# </div>
# <div class="_iul6hq" style="height: 51px; padding-bottom: 6px;">
# <div style="">
# <div class="_1qfi0x77 XDPRating" style="">
# <div class="rc-RatingLink" style="">
# <ul class="_2lnij6"
# style="font-size: 1em; outline-color: invert; outline-style: none; outline-width: 0px; margin-top: 0px; list-style-type: none; padding-left: 0px;">
# <li class="_36rlri rc-NavItem" style=""><a
# data-click-key="xdp_v1.xdp.click.nav_item_reviews"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;#reviews&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;nav_item_reviews&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click" data-track-component="nav_item_reviews"
# data-track-href="#reviews"
# href="https://www.coursera.org/learn/python-for-applied-data-science-ai?specialization=ibm-data-science#reviews"
# to="#reviews" class="_1jpd6ix" data-active="false"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(136, 136, 136); text-decoration: none;">
# <div class="_1srkxe1s XDPRating" style="">
# <div data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click" data-track-component="banner_star_rating"
# role="presentation" data-test="star-rating"
# style="border-bottom: medium none;">
# <div aria-hidden="true" class="_1mzojlvw" role="img"
# style="position: relative; cursor: inherit;"><span
# class="_13xsef79 d-inline-block" style="cursor: inherit;"><svg
# aria-hidden="true" class="_ufjrdd" viewbox="0 0 46 44" role="img"
# aria-labelledby="FilledStar100a1b32-290a-406b-800c-0738aa063425 FilledStar100a1b32-290a-406b-800c-0738aa063425Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(247, 187, 86); height: 14px; width: 14px; margin-right: 2px; vertical-align: text-bottom;"><path
# stroke="#7C6919" stroke-width="3"
# d="M23 36.5L8.893 43.916l2.694-15.708L.175 17.084l15.772-2.292L23 .5l7.053 14.292 15.772 2.292-11.412 11.124 2.694 15.708z"
# fill-rule="evenodd" role="presentation"></path></svg></span><span
# class="_13xsef79 d-inline-block" style="cursor: inherit;"><svg
# aria-hidden="true" class="_ufjrdd" viewbox="0 0 46 44" role="img"
# aria-labelledby="FilledStarf178b708-27c6-42bc-e01f-0df391f4bcda FilledStarf178b708-27c6-42bc-e01f-0df391f4bcdaDesc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(247, 187, 86); height: 14px; width: 14px; margin-right: 2px; vertical-align: text-bottom;"><path
# stroke="#7C6919" stroke-width="3"
# d="M23 36.5L8.893 43.916l2.694-15.708L.175 17.084l15.772-2.292L23 .5l7.053 14.292 15.772 2.292-11.412 11.124 2.694 15.708z"
# fill-rule="evenodd" role="presentation"></path></svg></span><span
# class="_13xsef79 d-inline-block" style="cursor: inherit;"><svg
# aria-hidden="true" class="_ufjrdd" viewbox="0 0 46 44" role="img"
# aria-labelledby="FilledStare4c98f9c-c389-4878-d4b3-217550b9057b FilledStare4c98f9c-c389-4878-d4b3-217550b9057bDesc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(247, 187, 86); height: 14px; width: 14px; margin-right: 2px; vertical-align: text-bottom;"><path
# stroke="#7C6919" stroke-width="3"
# d="M23 36.5L8.893 43.916l2.694-15.708L.175 17.084l15.772-2.292L23 .5l7.053 14.292 15.772 2.292-11.412 11.124 2.694 15.708z"
# fill-rule="evenodd" role="presentation"></path></svg></span><span
# class="_13xsef79 d-inline-block" style="cursor: inherit;"><svg
# aria-hidden="true" class="_ufjrdd" viewbox="0 0 46 44" role="img"
# aria-labelledby="FilledStar5ff240f5-a557-4e1f-e5fd-66f514424a89 FilledStar5ff240f5-a557-4e1f-e5fd-66f514424a89Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(247, 187, 86); height: 14px; width: 14px; margin-right: 2px; vertical-align: text-bottom;"><path
# stroke="#7C6919" stroke-width="3"
# d="M23 36.5L8.893 43.916l2.694-15.708L.175 17.084l15.772-2.292L23 .5l7.053 14.292 15.772 2.292-11.412 11.124 2.694 15.708z"
# fill-rule="evenodd" role="presentation"></path></svg></span><span
# class="_13xsef79 d-inline-block" style="cursor: inherit;"><svg
# aria-hidden="true" class="_ufjrdd" viewbox="0 0 46 44" role="img"
# aria-labelledby="HalfFadedStar1010a077-0531-41d4-d7a1-d2542ca7928b HalfFadedStar1010a077-0531-41d4-d7a1-d2542ca7928bDesc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(247, 187, 86); height: 14px; width: 14px; margin-right: 2px; vertical-align: text-bottom;"><g
# role="presentation"><path
# d="M22.825 36L8.72 43.416l2.694-15.708L0 16.584l15.772-2.292L22.825 0z"
# stroke-width="3" stroke="#7C6919"></path><polygon fill="#FFF"
# stroke-width="3" stroke="#7C6919"
# points="22.8253564 36 22.8253564 2.34479103e-13 29.8787794 14.2917961 45.6507128 16.5835921 34.2380346 27.7082039 36.9322024 43.4164079"></polygon></g></svg></span></div>
# </div>
# <span
# class="_16ni8zai m-b-0 rating-text number-rating number-rating-expertise"
# data-test="number-star-rating"
# style="margin-bottom: 0px ! important; font-size: 14px; line-height: 19px; font-weight: bold; font-family: OpenSans-Bold,OpenSans,Arial,sans-serif; margin-left: 6px; margin-right: 6px; color: rgb(247, 187, 86);">4.6
# <div class="screenreader-only"
# style="border: 0px none ; margin: -1px; padding: 0px; overflow: hidden; position: absolute; width: 1px; height: 1px; clip: rect(0px, 0px, 0px, 0px);">stars</div>
# </span>
# <div class="_wmgtrl9 color-white ratings-count-expertise-style"
# style="color: rgb(255, 255, 255); font-size: 14px; line-height: 19px; font-weight: normal; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; margin-right: 6px;"><span
# data-test="ratings-count-without-asterisks" style=""><span style="">26,668
# ratings</span></span></div>
# </div>
# </a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="_12gv18d9" style="">
# <div
# class="rc-BannerInstructorInfo rc-BannerInstructorInfo__seo-experiment"
# style="padding-top: 8px; height: auto;">
# <div class="_2lnij6" style="list-style-type: none; padding-left: 0px;">
# <div class="_y1d9czk" style=""><a
# data-click-key="xdp_v1.xdp.click.nav_item_instructors"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;#instructors&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;nav_item_instructors&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click" data-track-component="nav_item_instructors"
# data-track-href="#instructors"
# href="https://www.coursera.org/learn/python-for-applied-data-science-ai?specialization=ibm-data-science#instructors"
# to="#instructors"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(255, 255, 255); text-decoration: none; font-size: 14px; line-height: 19px;">
# <div class="_1qfi0x77" style="">
# <div class="_1qfi0x77" style=""><img
# src="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-instructor-photos.s3.amazonaws.com/19/c6bf4030a611e897095b4bb8907d1a/joseph.jpg?auto=format%2Ccompress&amp;dpr=1&amp;w=36&amp;h="
# srcset="https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-instructor-photos.s3.amazonaws.com/19/c6bf4030a611e897095b4bb8907d1a/joseph.jpg?auto=format%2Ccompress&amp;dpr=2&amp;w=36&amp;h= 2x, https://d3njjcbhbojbot.cloudfront.net/api/utilities/v1/imageproxy/https://coursera-instructor-photos.s3.amazonaws.com/19/c6bf4030a611e897095b4bb8907d1a/joseph.jpg?auto=format%2Ccompress&amp;dpr=3&amp;w=36&amp;h= 3x"
# class="_1c0nwk" alt="Image of instructor, Joseph Santarcangelo"
# role="presentation"
# style="border: 0px none ; overflow: hidden; vertical-align: middle; color: rgb(255, 255, 255); background-color: rgb(42, 115, 204); max-width: 36px; font-size: 18px; height: 36px; width: 36px; margin-right: 8px;"><span
# style="">Joseph Santarcangelo</span>&nbsp;&nbsp;</div>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div>
# <br>
# </body>
# </html>

# %% [markdown]
# Joseph Santarcangelo
# Ph.D., Data Scientist at IBM
#
# IBM

# %% [markdown]
# <html>
# <head>
# <meta content="text/html; charset=ISO-8859-1"
# http-equiv="content-type">
# <title></title>
# </head>
# <body>
# <h2 class="m-r-1 m-b-0 bold headline-4-text"
# style="padding: 0px; margin-top: 0px; margin-bottom: 0px ! important; margin-left: 0px; max-width: 100%; font-family: OpenSans,Arial,sans-serif; font-size: 24px; line-height: 30px; font-weight: 400; color: rgb(55, 58, 60); font-style: normal; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255); vertical-align: middle;">About
# this Course</h2>
# <div class="rc-ProductMetrics"
# style="margin-right: 30px; color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <div class="_bd90rg"
# style="font-size: 14px; color: rgb(102, 102, 102); font-weight: bold;"><span
# style=""><span style=""><br>
# </span></span></div>
# </div>
# <div class="m-t-1 description"
# style="color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <div class="rc-TogglableContent about-section" style="">
# <div class="content" style="position: relative; height: auto;">
# <div class="content-inner" style="">
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">Kickstart
# your learning of Python for data science, as well as programming in
# general, with this beginner-friendly introduction to Python. Python is
# one of the world’s most popular programming languages, and there has
# never been greater demand for professionals with the ability to apply
# Python fundamentals to drive business solutions across industries. </p>
# <p aria-hidden="false"
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">This
# course will take you from zero to programming in Python in a matter of
# hours—no prior programming experience necessary! You will learn Python
# fundamentals, including data structures and data analysis, complete
# hands-on exercises throughout the course modules, and create a final
# project to demonstrate your new skills. By the end of this course,
# you’ll feel comfortable creating basic programs, working with data, and
# solving real-world problems in Python. You’ll gain a strong foundation
# for more advanced learning in the field, and develop skills to help
# advance your career. This course can be applied to multiple
# Specialization or Professional Certificate programs. Completing this
# course will count towards your learning in any of the following
# programs: IBM Applied AI Professional Certificate Applied Data Science
# Specialization IBM Data Science Professional Certificate Upon
# completion of any of the above programs, in addition to earning a
# Specialization completion certificate from Coursera, you’ll also
# receive a digital badge from IBM recognizing your expertise in the
# field.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="m-y-2"
# style="color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <div class="CourseSpecializationList" style="">
# <div class="_lriijlm m-t-1"
# style="font-weight: normal; font-family: OpenSans-Light,OpenSans,Arial,sans-serif;">This
# course is part of multiple programs</div>
# <div class="m-t-1" style="">This course can be applied to multiple
# Specializations or Professional Certificates programs. Completing this
# course will count towards your learning in any of the following
# programs:</div>
# <ul class="m-t-1"
# style="font-size: 1em; outline-color: invert; outline-style: none; outline-width: 0px;">
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/data-science-fundamentals-python-sql&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;data-science-fundamentals-python-sql&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/data-science-fundamentals-python-sql"
# href="https://www.coursera.org/specializations/data-science-fundamentals-python-sql"
# to="/specializations/data-science-fundamentals-python-sql"
# target="_blank" rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">Data
# Science Fundamentals with Python and SQL Specialization</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/applied-data-science&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;applied-data-science&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/applied-data-science"
# href="https://www.coursera.org/specializations/applied-data-science"
# to="/specializations/applied-data-science" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">Applied
# Data Science Specialization</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/ibm-data-analyst&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;ibm-data-analyst&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/ibm-data-analyst"
# href="https://www.coursera.org/specializations/ibm-data-analyst"
# to="/specializations/ibm-data-analyst" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">IBM
# Data Analyst Professional Certificate</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/ibm-full-stack-cloud-developer&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;ibm-full-stack-cloud-developer&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/ibm-full-stack-cloud-developer"
# href="https://www.coursera.org/specializations/ibm-full-stack-cloud-developer"
# to="/specializations/ibm-full-stack-cloud-developer" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">IBM
# Full Stack Software Developer Professional Certificate</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/ibm-data-engineer&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;ibm-data-engineer&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/ibm-data-engineer"
# href="https://www.coursera.org/specializations/ibm-data-engineer"
# to="/specializations/ibm-data-engineer" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">IBM
# Data Engineering Professional Certificate</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/ibm-data-science&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;ibm-data-science&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/ibm-data-science"
# href="https://www.coursera.org/specializations/ibm-data-science"
# to="/specializations/ibm-data-science" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">IBM
# Data Science Professional Certificate</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/devops-and-software-engineering&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;devops-and-software-engineering&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/devops-and-software-engineering"
# href="https://www.coursera.org/specializations/devops-and-software-engineering"
# to="/specializations/devops-and-software-engineering" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">IBM
# DevOps and Software Engineering Professional Certificate</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/data-engineering-foundations&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;data-engineering-foundations&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/data-engineering-foundations"
# href="https://www.coursera.org/specializations/data-engineering-foundations"
# to="/specializations/data-engineering-foundations" target="_blank"
# rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">Data
# Engineering Foundations Specialization</a></li>
# <li class="m-t-1s" style=""><a
# data-click-key="xdp_v1.xdp.click.course_specialization_list_link"
# data-click-value="{&quot;courseId&quot;:&quot;ejOz7RDUEei99hK0xs-tsg&quot;,&quot;href&quot;:&quot;/specializations/applied-artifical-intelligence-ibm-watson-ai&quot;,&quot;namespace&quot;:{&quot;action&quot;:&quot;click&quot;,&quot;app&quot;:&quot;xdp_v1&quot;,&quot;component&quot;:&quot;course_specialization_list_link&quot;,&quot;page&quot;:&quot;xdp&quot;},&quot;s12nId&quot;:&quot;child~61XX8Y3TEey4CgqSbzoP7Q&quot;,&quot;schema_type&quot;:&quot;FRONTEND&quot;,&quot;slug&quot;:&quot;applied-artifical-intelligence-ibm-watson-ai&quot;}"
# data-track="true" data-track-app="xdp_v1" data-track-page="xdp"
# data-track-action="click"
# data-track-component="course_specialization_list_link"
# data-track-href="/specializations/applied-artifical-intelligence-ibm-watson-ai"
# href="https://www.coursera.org/specializations/applied-artifical-intelligence-ibm-watson-ai"
# to="/specializations/applied-artifical-intelligence-ibm-watson-ai"
# target="_blank" rel="noopener noreferrer"
# style="background: transparent none repeat scroll 0%; -moz-background-clip: -moz-initial; -moz-background-origin: -moz-initial; -moz-background-inline-policy: -moz-initial; color: rgb(0, 98, 228); text-decoration: none;">IBM
# Applied AI Professional Certificate</a></li>
# </ul>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# <H1>Study Weeks</H1>
# <ul>
#     <li><a href="Week1/week1.ipynb">week1</a></li>
#     <li><a href="Week2/week2.ipynb">week2</a></li>
#     <li><a href="Week3/week3.ipynb">week3</a></li>
#     <li><a href="Week4/week4.ipynb">week4</a></li>
#     <li><a href="Week5/week5.ipynb">week5</a></li>
# </ul>
