# %% [markdown]
# <html>
# <head>
# <meta content="text/html; charset=ISO-8859-1"
# http-equiv="content-type">
# <title></title>
# </head>
# <body>
# <div class="CmlLearningObjectives border-a p-x-2 p-t-1"
# style="border: 1px solid rgb(227, 228, 229); color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <h3 class="_1fe1gic7 text-secondary text-uppercase m-b-2"
# style="padding: 0px; margin-top: 0px; margin-right: 0px; margin-left: 0px; max-width: 100%; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; font-weight: bold; color: rgb(110, 118, 127); text-transform: uppercase ! important;">WHAT
# YOU WILL LEARN</h3>
# <ul class="_jyhj5r list-style-none p-a-0 p-l-1 m-b-0"
# style="font-size: 1em; outline-color: invert; outline-style: none; outline-width: 0px; margin-bottom: 0px ! important; margin-top: 0px; list-style-type: none; list-style-image: none; list-style-position: outside; margin-left: -12px; margin-right: -12px;">
# <div class="_1yuv87zj m-b-1"
# style="position: relative; min-height: 1px; width: 350px; padding-left: 12px; padding-right: 12px;">
# <li class="_y1d9czk m-b-1s" style=""><span class="m-r-1" style=""><svg
# class="_ufjrdd" aria-hidden="true" focusable="false"
# style="fill: rgb(31, 131, 84); height: 24px; width: 24px;"
# viewbox="0 0 48 48" role="img"
# aria-labelledby="Checka8c3544c-4c3d-424c-84a4-cef49a802a60 Checka8c3544c-4c3d-424c-84a4-cef49a802a60Desc"
# xmlns="http://www.w3.org/2000/svg"><polygon
# points="17.4333333 31.6416667 8.85833333 23.0666667 6 25.925 17.4333333 37.3583333 41.9333333 12.8583333 39.075 10"
# role="presentation"></polygon></svg></span>
# <div class="_wmgtrl9"
# style="font-weight: normal; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; max-width: 90%;">
# <div id="" class="rc-CML show-soft-breaks" dir="auto" style="">
# <div style="">
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;"><em
# style="">Learn what data science is, the various activities of a data
# scientist’s job, and methodology to think and work like a data
# scientist&nbsp;</em>&nbsp;</p>
# </div>
# </div>
# </div>
# </li>
# </div>
# <div class="_1yuv87zj m-b-1"
# style="position: relative; min-height: 1px; width: 350px; padding-left: 12px; padding-right: 12px;">
# <li class="_y1d9czk m-b-1s" style=""><span class="m-r-1" style=""><svg
# class="_ufjrdd" aria-hidden="true" focusable="false"
# style="fill: rgb(31, 131, 84); height: 24px; width: 24px;"
# viewbox="0 0 48 48" role="img"
# aria-labelledby="Check2fe11e45-4d27-456c-da64-e310aefe8ad8 Check2fe11e45-4d27-456c-da64-e310aefe8ad8Desc"
# xmlns="http://www.w3.org/2000/svg"><polygon
# points="17.4333333 31.6416667 8.85833333 23.0666667 6 25.925 17.4333333 37.3583333 41.9333333 12.8583333 39.075 10"
# role="presentation"></polygon></svg></span>
# <div class="_wmgtrl9"
# style="font-weight: normal; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; max-width: 90%;">
# <div id="" class="rc-CML show-soft-breaks" dir="auto" style="">
# <div style="">
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;"><em
# style="">Develop hands-on skills using the tools</em><em style="">,
# languages, and libraries</em><em style=""> used by professional data
# scientists&nbsp;</em>&nbsp;</p>
# </div>
# </div>
# </div>
# </li>
# </div>
# <div class="_1yuv87zj m-b-1"
# style="position: relative; min-height: 1px; width: 350px; padding-left: 12px; padding-right: 12px;">
# <li class="_y1d9czk m-b-1s" style=""><span class="m-r-1" style=""><svg
# class="_ufjrdd" aria-hidden="true" focusable="false"
# style="fill: rgb(31, 131, 84); height: 24px; width: 24px;"
# viewbox="0 0 48 48" role="img"
# aria-labelledby="Checkb6e80010-4ebf-491d-9e57-958cee1204af Checkb6e80010-4ebf-491d-9e57-958cee1204afDesc"
# xmlns="http://www.w3.org/2000/svg"><polygon
# points="17.4333333 31.6416667 8.85833333 23.0666667 6 25.925 17.4333333 37.3583333 41.9333333 12.8583333 39.075 10"
# role="presentation"></polygon></svg></span>
# <div class="_wmgtrl9"
# style="font-weight: normal; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; max-width: 90%;">
# <div id="" class="rc-CML show-soft-breaks" dir="auto" style="">
# <div style="">
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;"><em
# style="">Import and clean data sets, analyze and visualize data, and
# build and evaluate machine learning models and pipelines using Python</em>&nbsp;</p>
# </div>
# </div>
# </div>
# </li>
# </div>
# <div class="_1yuv87zj m-b-1"
# style="position: relative; min-height: 1px; width: 350px; padding-left: 12px; padding-right: 12px;">
# <li class="_y1d9czk m-b-1s" style=""><span class="m-r-1" style=""><svg
# class="_ufjrdd" aria-hidden="true" focusable="false"
# style="fill: rgb(31, 131, 84); height: 24px; width: 24px;"
# viewbox="0 0 48 48" role="img"
# aria-labelledby="Checkb75a9cde-d6ea-4e94-d8b8-faa5f6ce6102 Checkb75a9cde-d6ea-4e94-d8b8-faa5f6ce6102Desc"
# xmlns="http://www.w3.org/2000/svg"><polygon
# points="17.4333333 31.6416667 8.85833333 23.0666667 6 25.925 17.4333333 37.3583333 41.9333333 12.8583333 39.075 10"
# role="presentation"></polygon></svg></span>
# <div class="_wmgtrl9"
# style="font-weight: normal; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; max-width: 90%;">
# <div id="" class="rc-CML show-soft-breaks" dir="auto" style="">
# <div style="">
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;"><em
# style="">Apply various data science skills, techniques, and tools to
# complete a project and publish a report&nbsp;</em>&nbsp;</p>
# </div>
# </div>
# </div>
# </li>
# </div>
# </ul>
# </div>
# <hr class="separator"
# style="border-width: 1px 0px 0px; border-top: 1px solid rgb(238, 238, 238); margin: 0px 24px; overflow: visible; height: 0px; color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <div
# class="Skills p-x-2 p-t-1 p-b-2 skills-combined-with-learning-objs border-a css-1rj0z6b"
# style="border: medium none ; margin-top: 13px; color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <h2 class="_1fe1gic7 text-secondary text-uppercase m-b-2"
# style="padding: 0px; margin-top: 0px; margin-right: 0px; margin-left: 0px; max-width: 100%; font-family: OpenSans,-apple-system,BlinkMacSystemFont,&quot;Segoe UI&quot;,Roboto,&quot;Helvetica Neue&quot;,Arial,sans-serif; font-weight: bold; color: rgb(110, 118, 127); text-transform: uppercase ! important;">SKILLS
# YOU WILL GAIN</h2>
# <div class="rc-TogglableContent collapsed" style="">
# <div class="content"
# style="overflow: hidden; position: relative; height: auto;">
# <div class="content-inner" style="">
# <div style="">
# <ul role="list" class="css-uqope5"
# style="margin: 0px; padding: 0px; font-size: 1em; outline-color: invert; outline-style: none; outline-width: 0px; list-style-type: none; list-style-image: none; list-style-position: outside;">
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Data Science</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Deep Learning</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Machine Learning</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Big Data</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Data Mining</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Github</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Python Programming</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Jupyter notebooks</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Rstudio</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Methodology</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Data Analysis</span></span></span></li>
# <li style=""><span class="_rsc0bd m-r-1s m-b-1s"
# style="border: medium none ; overflow: hidden; white-space: nowrap; color: rgb(31, 31, 31); background-color: rgb(235, 236, 237);"><span
# class="_x4x75x" style="margin: auto; overflow: hidden;"><span
# class="_1q9sh65" style="overflow: hidden;"></span><span
# class="_ontdeqt" style="overflow: hidden;">Pandas</span></span></span></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# <html>
# <head>
# <meta content="text/html; charset=ISO-8859-1"
# http-equiv="content-type">
# <title></title>
# </head>
# <body>
# <h2 class="m-r-1 m-b-0 bold headline-4-text"
# style="padding: 0px; margin-top: 0px; margin-bottom: 0px ! important; margin-left: 0px; max-width: 100%; font-family: OpenSans,Arial,sans-serif; font-size: 24px; line-height: 30px; font-weight: 400; color: rgb(55, 58, 60); font-style: normal; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255); vertical-align: middle;"><span
# style="">About this Professional Certificate</span></h2>
# <div class="rc-ProductMetrics"
# style="margin-right: 30px; color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
#
# </div>
# <div data-e2e="description" class="m-t-1 m-b-3 description"
# style="color: rgb(55, 58, 60); font-family: OpenSans,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: left; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <div class="description" style="">
# <div id="" class="rc-CML override-cml-headers show-soft-breaks"
# dir="auto" style="">
# <div style="">
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">Data
# science is one of the hottest professions of the decade, and the demand
# for data scientists who can analyze data and communicate results to
# inform data driven decisions has never been greater. This Professional
# Certificate from IBM will help anyone interested in pursuing a <strong
# style="font-weight: bolder; font-family: OpenSans-Bold,OpenSans,Arial,sans-serif;">career
# in data science</strong> or machine learning develop career-relevant
# skills and experience. </p>
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">It’s
# a myth that to become a data scientist you need a Ph.D. Anyone with a
# passion for learning can take this Professional Certificate – <strong
# style="font-weight: bolder; font-family: OpenSans-Bold,OpenSans,Arial,sans-serif;">no
# prior knowledge of computer science or programming languages required</strong>
# – and develop the skills, tools, and portfolio to have a competitive
# edge in the job market as an entry level data scientist.</p>
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">The
# program consists of 9 online courses that will provide you with the <strong
# style="font-weight: bolder; font-family: OpenSans-Bold,OpenSans,Arial,sans-serif;">latest
# job-ready tools and skills</strong>, including open source tools and
# libraries, Python, databases, SQL, data visualization, data analysis,
# statistical analysis, predictive modeling, and machine learning
# algorithms. You’ll learn data science through hands-on practice in the
# IBM Cloud using real data science tools and real-world data sets.</p>
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">Upon
# successfully completing these courses, you will have built a portfolio
# of data science projects to provide you with the confidence to plunge
# into an exciting profession in data science.</p>
# <p
# style="margin: 0px 0px 10px; font-size: 14px; line-height: 21px; font-family: OpenSans,Arial,sans-serif; max-width: 100%; font-weight: 400;">In
# addition to earning a Professional Certificate from Coursera, you'll
# also receive a <strong
# style="font-weight: bolder; font-family: OpenSans-Bold,OpenSans,Arial,sans-serif;">digital
# badge from IBM</strong> recognizing your proficiency in data science. </p>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# <html>
# <head>
# <meta content="text/html; charset=ISO-8859-1"
# http-equiv="content-type">
# <title></title>
# </head>
# <body>
# <h2 class="headline-4-text bold m-b-1"
# style="padding: 0px; margin-top: 0px; margin-right: 0px; margin-left: 0px; max-width: 100%; font-family: OpenSans,Arial,sans-serif; font-size: 24px; line-height: 30px; font-weight: 400; color: rgb(55, 58, 60); font-style: normal; letter-spacing: normal; orphans: 2; text-align: center; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);"><span
# style="">There are 10 Courses in this Professional Certificate</span></h2>
# </body>
# </html>

# %% [markdown]
# ***
