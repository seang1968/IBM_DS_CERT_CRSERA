# %% [markdown]
# <html>
# <head>
# </head>
# <body>
# <div class="css-3dqpno"
# style="margin-bottom: 48px; color: rgb(51, 51, 51); font-family: &quot;Helvetica Neue&quot;,Helvetica,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <h2 class="cds-137 css-15c9ksr cds-139"
# style="margin: 0px; padding: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; max-width: 100%; font-weight: 600; color: rgb(31, 31, 31); letter-spacing: -0.1px;">Practice
# Quiz</h2>
# <div class="css-ktfaw3" style="margin-top: 8px;"><span
# class="cds-137 css-1vjdgz cds-139"
# aria-label="Total available points 4"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(31, 31, 31);"><span
# aria-hidden="true" style=""><span style="">Total points<span>&nbsp;</span><span
# class="cds-137 css-1r9ruxl cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">4</span></span></span></span></div>
# </div>
# <div
# style="color: rgb(51, 51, 51); font-family: &quot;Helvetica Neue&quot;,Helvetica,Arial,sans-serif; font-size: 14px; font-style: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; white-space: normal; widows: 2; word-spacing: 0px; background-color: rgb(255, 255, 255);">
# <div role="group" class="rc-FormPartsQuestion"
# aria-labelledby="GsABrDO1EeuVUg5KuH9rrw-legend"
# style="width: 1197.65px; font-size: 14px; margin-top: 48px; margin-bottom: 48px;">
# <div id="GsABrDO1EeuVUg5KuH9rrw-legend"
# class="rc-FormPartsQuestion__row" data-test="legend" aria-hidden="true"
# style="">
# <div class="rc-FormPartsQuestion__numberCell"
# style="width: 30px; font-weight: 700;">
# <h3 class="cds-137 css-19ir7w5 cds-139" aria-hidden="true"
# style="margin: 0px; padding: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; max-width: 100%; font-weight: 700; color: rgb(31, 31, 31); letter-spacing: -0.1px;"><span
# style="">1</span>.</h3>
# <span class="screenreader-only"
# style="border: 0px none ; margin: -1px; padding: 0px; overflow: hidden; position: absolute; width: 1px; height: 1px; clip: rect(0px, 0px, 0px, 0px);"><span
# style="">Question 1</span></span></div>
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 1051.86px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1051.86px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">Consider
# the following set: <strong
# style="font-weight: 700; font-family: unset;">{"A","A"}</strong>, what
# will the result be when the set is created? </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__pointsCell" style="width: 136px;">
# <div class="css-1xe0vjc"
# style="padding: 4px; background-color: rgb(229, 231, 232);"><span
# class="cds-137 css-1vjdgz cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(31, 31, 31);"><span
# style=""><span dir="ltr" style="">1<span>&nbsp;</span>/<span>&nbsp;</span>1</span><span>&nbsp;</span>point</span></span></div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__row" style="margin-top: 13px;">
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div style="">
# <div class="css-1mkdutb" style="">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioUnchecked3d76fea7-682b-4ba7-8c50-78e367fdbcc3 RadioUnchecked3d76fea7-682b-4ba7-8c50-78e367fdbcc3Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="GsABrDO1EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.8009699168463045"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">
# {"A","A"}</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div class="css-1mkdutb" style="margin-top: 12px;">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox cui-isChecked"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioChecked1c53bd84-0b1a-41ba-aa59-cf92dd17fa12 RadioChecked1c53bd84-0b1a-41ba-aa59-cf92dd17fa12Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 7c-2.76 0-5 2.24-5 5s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5zm0-5C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="GsABrDO1EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.541625723138274" checked="checked"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">
# {"A"} </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div data-test="GradeFeedback-success" class="css-gl00bw"
# style="padding: 12px; margin-top: 16px; background-color: rgb(247, 251, 249);">
# <div data-test="GradeFeedback-icon" class="css-1aox1q8"
# style="margin-right: 8px; height: 20px;"><svg aria-hidden="true"
# fill="none" focusable="false" height="20" viewbox="0 0 20 20"
# width="20" id="cds-3904" class="css-md7hvk"><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M10 1.5a8.5 8.5 0 100 17 8.5 8.5 0 000-17zM.5 10a9.5 9.5 0 1119 0 9.5 9.5 0 01-19 0z"
# fill="currentColor"></path><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M14.384 7.32l-5.35 6.42-3.388-3.386.708-.708 2.612 2.613 4.65-5.58.768.641z"
# fill="currentColor"></path></svg></div>
# <div class="css-8atqhb" style="width: 999.872px;">
# <div data-test="GradeFeedback-info" class="css-qbubgm"
# style="margin-left: 0px;">
# <div class="cds-137 css-7lngrb cds-139"
# data-test="GradeFeedback-caption"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(29, 124, 80);">Correct</div>
# <div class="cds-137 css-1r9ruxl cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 999.872px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 999.872px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">correct,
# there are no duplicate values in a set </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div role="group" class="rc-FormPartsQuestion"
# aria-labelledby="mwKPgDO3EeuDbBLbfoZxSw-legend"
# style="width: 1197.65px; font-size: 14px; margin-top: 66px; margin-bottom: 48px;">
# <div id="mwKPgDO3EeuDbBLbfoZxSw-legend"
# class="rc-FormPartsQuestion__row" data-test="legend" aria-hidden="true"
# style="">
# <div class="rc-FormPartsQuestion__numberCell"
# style="width: 30px; font-weight: 700;">
# <h3 class="cds-137 css-19ir7w5 cds-139" aria-hidden="true"
# style="margin: 0px; padding: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; max-width: 100%; font-weight: 700; color: rgb(31, 31, 31); letter-spacing: -0.1px;"><span
# style="">2</span>.</h3>
# <span class="screenreader-only"
# style="border: 0px none ; margin: -1px; padding: 0px; overflow: hidden; position: absolute; width: 1px; height: 1px; clip: rect(0px, 0px, 0px, 0px);"><span
# style="">Question 2</span></span></div>
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 1051.86px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1051.86px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">What
# is the result of the following: <strong
# style="font-weight: 700; font-family: unset;">type(set([1,2,3]))</strong></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__pointsCell" style="width: 136px;">
# <div class="css-1xe0vjc"
# style="padding: 4px; background-color: rgb(229, 231, 232);"><span
# class="cds-137 css-1vjdgz cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(31, 31, 31);"><span
# style=""><span dir="ltr" style="">1<span>&nbsp;</span>/<span>&nbsp;</span>1</span><span>&nbsp;</span>point</span></span></div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__row" style="margin-top: 13px;">
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div style="">
# <div class="css-1mkdutb" style="">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox cui-isChecked"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioChecked43143461-611d-4090-b297-3731fa5f8b11 RadioChecked43143461-611d-4090-b297-3731fa5f8b11Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 7c-2.76 0-5 2.24-5 5s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5zm0-5C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="mwKPgDO3EeuDbBLbfoZxSw" readonly="readonly" tabindex="0"
# value="0.4155435527768254" checked="checked"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">set</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div class="css-1mkdutb" style="margin-top: 12px;">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioUnchecked8d3fb3b9-4227-4c3a-b95b-fb4dc3646df3 RadioUnchecked8d3fb3b9-4227-4c3a-b95b-fb4dc3646df3Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="mwKPgDO3EeuDbBLbfoZxSw" readonly="readonly" tabindex="0"
# value="0.9022290745371351"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 27.9972px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <h2
# style="padding: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; font-weight: 600; color: inherit; letter-spacing: -0.1px;">list</h2>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div data-test="GradeFeedback-success" class="css-gl00bw"
# style="padding: 12px; margin-top: 16px; background-color: rgb(247, 251, 249);">
# <div data-test="GradeFeedback-icon" class="css-1aox1q8"
# style="margin-right: 8px; height: 20px;"><svg aria-hidden="true"
# fill="none" focusable="false" height="20" viewbox="0 0 20 20"
# width="20" id="cds-3906" class="css-md7hvk"><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M10 1.5a8.5 8.5 0 100 17 8.5 8.5 0 000-17zM.5 10a9.5 9.5 0 1119 0 9.5 9.5 0 01-19 0z"
# fill="currentColor"></path><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M14.384 7.32l-5.35 6.42-3.388-3.386.708-.708 2.612 2.613 4.65-5.58.768.641z"
# fill="currentColor"></path></svg></div>
# <div class="css-8atqhb" style="width: 999.872px;">
# <div data-test="GradeFeedback-info" class="css-qbubgm"
# style="margin-left: 0px;">
# <div class="cds-137 css-7lngrb cds-139"
# data-test="GradeFeedback-caption"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(29, 124, 80);">Correct</div>
# <div class="cds-137 css-1r9ruxl cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 999.872px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 999.872px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">correct,
# the function <strong style="font-weight: 700; font-family: unset;">set
# </strong>casts the list to a set before we apply the <strong
# style="font-weight: 700; font-family: unset;">type </strong>function </p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div role="group" class="rc-FormPartsQuestion"
# aria-labelledby="nVyscDO3EeuVUg5KuH9rrw-legend"
# style="width: 1197.65px; font-size: 14px; margin-top: 66px; margin-bottom: 48px;">
# <div id="nVyscDO3EeuVUg5KuH9rrw-legend"
# class="rc-FormPartsQuestion__row" data-test="legend" aria-hidden="true"
# style="">
# <div class="rc-FormPartsQuestion__numberCell"
# style="width: 30px; font-weight: 700;">
# <h3 class="cds-137 css-19ir7w5 cds-139" aria-hidden="true"
# style="margin: 0px; padding: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; max-width: 100%; font-weight: 700; color: rgb(31, 31, 31); letter-spacing: -0.1px;"><span
# style="">3</span>.</h3>
# <span class="screenreader-only"
# style="border: 0px none ; margin: -1px; padding: 0px; overflow: hidden; position: absolute; width: 1px; height: 1px; clip: rect(0px, 0px, 0px, 0px);"><span
# style="">Question 3</span></span></div>
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 1051.86px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1051.86px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">What
# method do you use to add an element to a set?</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__pointsCell" style="width: 136px;">
# <div class="css-1xe0vjc"
# style="padding: 4px; background-color: rgb(229, 231, 232);"><span
# class="cds-137 css-1vjdgz cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(31, 31, 31);"><span
# style=""><span dir="ltr" style="">1<span>&nbsp;</span>/<span>&nbsp;</span>1</span><span>&nbsp;</span>point</span></span></div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__row" style="margin-top: 13px;">
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div style="">
# <div class="css-1mkdutb" style="">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox cui-isChecked"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioChecked11a2fe09-d793-43ed-8324-11ba52661038 RadioChecked11a2fe09-d793-43ed-8324-11ba52661038Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 7c-2.76 0-5 2.24-5 5s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5zm0-5C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="nVyscDO3EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.29768314921440875" checked="checked"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">add</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div class="css-1mkdutb" style="margin-top: 12px;">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioUnchecked6074e4ce-1082-4a93-94f3-5540479fad59 RadioUnchecked6074e4ce-1082-4a93-94f3-5540479fad59Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="nVyscDO3EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.017620374494392133"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">extend</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div class="css-1mkdutb" style="margin-top: 12px;">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioUnchecked9cfb5da8-8c9c-43bf-c76d-fa2cab0cfac3 RadioUnchecked9cfb5da8-8c9c-43bf-c76d-fa2cab0cfac3Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="nVyscDO3EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.12257123945332205"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">append</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div data-test="GradeFeedback-success" class="css-gl00bw"
# style="padding: 12px; margin-top: 16px; background-color: rgb(247, 251, 249);">
# <div data-test="GradeFeedback-icon" class="css-1aox1q8"
# style="margin-right: 8px; height: 20px;"><svg aria-hidden="true"
# fill="none" focusable="false" height="20" viewbox="0 0 20 20"
# width="20" id="cds-3908" class="css-md7hvk"><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M10 1.5a8.5 8.5 0 100 17 8.5 8.5 0 000-17zM.5 10a9.5 9.5 0 1119 0 9.5 9.5 0 01-19 0z"
# fill="currentColor"></path><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M14.384 7.32l-5.35 6.42-3.388-3.386.708-.708 2.612 2.613 4.65-5.58.768.641z"
# fill="currentColor"></path></svg></div>
# <div class="css-8atqhb" style="width: 999.872px;">
# <div data-test="GradeFeedback-info" class="css-qbubgm"
# style="margin-left: 0px;">
# <div class="cds-137 css-7lngrb cds-139"
# data-test="GradeFeedback-caption"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(29, 124, 80);">Correct</div>
# <div class="cds-137 css-1r9ruxl cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 999.872px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 999.872px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">correct</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div role="group" class="rc-FormPartsQuestion"
# aria-labelledby="nslb0TO3EeuVUg5KuH9rrw-legend"
# style="width: 1197.65px; font-size: 14px; margin-top: 66px; margin-bottom: 48px;">
# <div id="nslb0TO3EeuVUg5KuH9rrw-legend"
# class="rc-FormPartsQuestion__row" data-test="legend" aria-hidden="true"
# style="">
# <div class="rc-FormPartsQuestion__numberCell"
# style="width: 30px; font-weight: 700;">
# <h3 class="cds-137 css-19ir7w5 cds-139" aria-hidden="true"
# style="margin: 0px; padding: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; max-width: 100%; font-weight: 700; color: rgb(31, 31, 31); letter-spacing: -0.1px;"><span
# style="">4</span>.</h3>
# <span class="screenreader-only"
# style="border: 0px none ; margin: -1px; padding: 0px; overflow: hidden; position: absolute; width: 1px; height: 1px; clip: rect(0px, 0px, 0px, 0px);"><span
# style="">Question 4</span></span></div>
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 1051.86px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1051.86px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">What
# is the result of the following operation : <strong
# style="font-weight: 700; font-family: unset;">{'a','b'} &amp;{'a'}</strong></p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__pointsCell" style="width: 136px;">
# <div class="css-1xe0vjc"
# style="padding: 4px; background-color: rgb(229, 231, 232);"><span
# class="cds-137 css-1vjdgz cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(31, 31, 31);"><span
# style=""><span dir="ltr" style="">1<span>&nbsp;</span>/<span>&nbsp;</span>1</span><span>&nbsp;</span>point</span></span></div>
# </div>
# </div>
# <div class="rc-FormPartsQuestion__row" style="margin-top: 13px;">
# <div class="rc-FormPartsQuestion__contentCell" style="width: 1051.86px;">
# <div style="">
# <div class="css-1mkdutb" style="">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox cui-isChecked"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioCheckedf27530e3-3320-418e-e32b-cf0059690829 RadioCheckedf27530e3-3320-418e-e32b-cf0059690829Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 7c-2.76 0-5 2.24-5 5s2.24 5 5 5 5-2.24 5-5-2.24-5-5-5zm0-5C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="nslb0TO3EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.8918091849444034" checked="checked"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">{'a'}</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div class="css-1mkdutb" style="margin-top: 12px;">
# <div class="rc-Option rc-Option--isReadOnly" style=""><label
# class="_1xzd2vdb cui-Checkbox"
# style="margin-bottom: 0px; font-weight: 700; white-space: nowrap; outline-color: invert; outline-style: none; outline-width: medium; position: relative; line-height: 1; vertical-align: middle; width: 1051.86px;"><span
# class="_1e7axzp" style=""><svg class="_ufjrdd" aria-hidden="true"
# focusable="false" viewbox="0 0 24 24" role="img"
# aria-labelledby="RadioUnchecked04271330-532f-450a-b5f9-85924359f838 RadioUnchecked04271330-532f-450a-b5f9-85924359f838Desc"
# xmlns="http://www.w3.org/2000/svg"
# style="fill: rgb(102, 102, 102); height: 24px; width: 24px;"><path
# d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zm0 18c-4.42 0-8-3.58-8-8s3.58-8 8-8 8 3.58 8 8-3.58 8-8 8z"
# role="presentation"></path></svg></span><input class="_gx2lzf"
# name="nslb0TO3EeuVUg5KuH9rrw" readonly="readonly" tabindex="0"
# value="0.38207193364569236"
# style="margin: 0px; padding: 0px; overflow: visible; color: inherit; font-style: inherit; font-variant: inherit; font-weight: inherit; font-stretch: inherit; font-family: inherit; position: absolute; width: 1051.86px; height: 23.9986px; z-index: auto ! important; opacity: 0; display: block;"
# type="radio"><span class="_bc4egv p-x-1s font-weight-normal"
# style="font-weight: 400;">
# <div class="cds-137 css-mpxffp cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id=""
# class="rc-RenderableHtml rc-CML rc-Option__input-text show-soft-breaks css-z95mbv"
# dir="auto" style="position: relative; z-index: 1; width: 1011.87px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 1011.87px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">{'a','b'}</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </span></label></div>
# </div>
# <div data-test="GradeFeedback-success" class="css-gl00bw"
# style="padding: 12px; margin-top: 16px; background-color: rgb(247, 251, 249);">
# <div data-test="GradeFeedback-icon" class="css-1aox1q8"
# style="margin-right: 8px; height: 20px;"><svg aria-hidden="true"
# fill="none" focusable="false" height="20" viewbox="0 0 20 20"
# width="20" id="cds-3910" class="css-md7hvk"><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M10 1.5a8.5 8.5 0 100 17 8.5 8.5 0 000-17zM.5 10a9.5 9.5 0 1119 0 9.5 9.5 0 01-19 0z"
# fill="currentColor"></path><path fill-rule="evenodd"
# clip-rule="evenodd"
# d="M14.384 7.32l-5.35 6.42-3.388-3.386.708-.708 2.612 2.613 4.65-5.58.768.641z"
# fill="currentColor"></path></svg></div>
# <div class="css-8atqhb" style="width: 999.872px;">
# <div data-test="GradeFeedback-info" class="css-qbubgm"
# style="margin-left: 0px;">
# <div class="cds-137 css-7lngrb cds-139"
# data-test="GradeFeedback-caption"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 700; letter-spacing: -0.1px; color: rgb(29, 124, 80);">Correct</div>
# <div class="cds-137 css-1r9ruxl cds-139"
# style="margin: 0px; font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; font-weight: 400; letter-spacing: 0px; color: rgb(31, 31, 31);">
# <div class="rc-CDSToCMLStylesheet css-z542kk" style="">
# <div id="" class="rc-RenderableHtml rc-CML show-soft-breaks css-z95mbv"
# dir="auto" style="width: 999.872px;">
# <div style="">
# <div class="cmlToHtml-content-container"
# style="width: 999.872px; margin-bottom: 0px ! important;">
# <p
# style="font-family: &quot;Source Sans Pro&quot;,Arial,sans-serif; margin-top: 0px; margin-bottom: 0px ! important; max-width: 100%; margin-right: 0px; margin-left: 0px; letter-spacing: 0px; font-weight: 400; min-height: 24px;">Correct,
# the intersection operation finds the elements that are in both sets.</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ![image.png](attachment:105cdc40-a74d-418d-93d8-be8a92a619bf.png)
